# %%
import epa.model.workflow
#model_set1 = epa.model.workflow.violation_state()
model_set1 = epa.model.workflow.violation_state_manifest_br_added()


from drain import step
step.OUTPUTDIR = '/mnt/data/nysdec/epa-ny/drain/'

# %%
step.load(model_set1)
# Out:
# [FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True)]

# %%
model_set1[1].get_result()['feature_importances']
# Out:
#                                                feature  importance
# 644             handlers_facility_all_receive_date_max    0.026943
# 651              manifest_facility_5y_line_items_count    0.014390
# 671              manifest_facility_all_approx_qty_mean    0.014233
# 647               manifest_facility_5y_approx_qty_mean    0.014229
# 675             manifest_facility_all_line_items_count    0.013687
# 646                manifest_facility_5y_approx_qty_max    0.013478
# 670               manifest_facility_all_approx_qty_max    0.013463
# 650                manifest_facility_5y_approx_qty_std    0.013295
# 674               manifest_facility_all_approx_qty_std    0.012855
# 673              manifest_facility_all_approx_qty_skew    0.012603
# 659               manifest_facility_1y_approx_qty_mean    0.012319
# 672               manifest_facility_all_approx_qty_min    0.012290
# 648                manifest_facility_5y_approx_qty_min    0.011930
# 649               manifest_facility_5y_approx_qty_skew    0.011753
# 660                manifest_facility_1y_approx_qty_min    0.011731
# 42                                         handler_age    0.011693
# 662                manifest_facility_1y_approx_qty_std    0.011576
# 658                manifest_facility_1y_approx_qty_max    0.011361
# 663              manifest_facility_1y_line_items_count    0.011337
# 570             handlers_facility_all_handler_sqg_prop    0.011145
# 661               manifest_facility_1y_approx_qty_skew    0.010073
# 607  handlers_facility_all_handler_location_eq_mail...    0.008797
# 401    investigations_facility_all_start_date_days_min    0.008678
# 321         investigations_facility_all_violation_prop    0.008337
# 396  investigations_facility_all_actual_return_to_c...    0.007682
# 347    investigations_facility_all_start_date_days_max    0.007652
# 571           handlers_facility_all_handler_cesqg_prop    0.007643
# 563                        handlers_facility_all_count    0.007218
# 483              handlers_facility_5y_receive_date_max    0.007194
# 568   handlers_facility_all_handler_not_generator_prop    0.007174
# ..                                                 ...         ...
# 701  icis_fec_facility_1y_total_penalty_assessed_am...    0.000000
# 702  icis_fec_facility_1y_total_penalty_assessed_am...    0.000000
# 457  handlers_facility_5y_handler_land_type_unknown...    0.000000
# 346   investigations_facility_all_not_subtitle_c_count    0.000000
# 296         investigations_facility_1y_final_count_sum    0.000000
# 203  investigations_facility_5y_expenditure_amount_max    0.000000
# 618  handlers_facility_all_handler_land_type_unknow...    0.000000
# 206  investigations_facility_5y_expenditure_amount_sum    0.000000
# 284  investigations_facility_1y_final_monetary_amou...    0.000000
# 285         investigations_facility_1y_paid_amount_max    0.000000
# 286        investigations_facility_1y_paid_amount_mean    0.000000
# 417  handlers_facility_5y_handler_land_type_unknown...    0.000000
# 231  investigations_facility_1y_formal_enforcement_epa    0.000000
# 287         investigations_facility_1y_paid_amount_min    0.000000
# 288         investigations_facility_1y_paid_amount_sum    0.000000
# 289  investigations_facility_1y_proposed_penalty_am...    0.000000
# 496  handlers_facility_1y_handler_land_type_unknown...    0.000000
# 636  handlers_facility_all_handler_used_oil_refiner...    0.000000
# 639     handlers_facility_all_handler_university_count    0.000000
# 640  handlers_facility_all_handler_teaching_hospita...    0.000000
# 641      handlers_facility_all_handler_nonprofit_count    0.000000
# 494  handlers_facility_1y_handler_land_type_other_prop    0.000000
# 216  investigations_facility_5y_sep_completion_over...    0.000000
# 293         investigations_facility_1y_final_count_max    0.000000
# 294        investigations_facility_1y_final_count_mean    0.000000
# 490  handlers_facility_1y_handler_land_type_tribal_...    0.000000
# 209         investigations_facility_5y_final_count_min    0.000000
# 208        investigations_facility_5y_final_count_mean    0.000000
# 207         investigations_facility_5y_final_count_max    0.000000
# 830                                         region_2.0    0.000000
#
# [831 rows x 2 columns]

# %%
from drain import explore, model

# %%
df_forest = explore.to_dataframe(model_set1).query('train_years ==5')

# %%
df_forest = explore.to_dataframe(model_set1)

# %%
df_forest.head()
# Out:
#    train_years  year                                               step
# 0            2  2012  FitPredict(inputs=[Construct(__class_name__='s...
# 1            2  2013  FitPredict(inputs=[Construct(__class_name__='s...
# 2            2  2014  FitPredict(inputs=[Construct(__class_name__='s...
# 3            2  2015  FitPredict(inputs=[Construct(__class_name__='s...
# 4            3  2012  FitPredict(inputs=[Construct(__class_name__='s...

# %%
# %matplotlib inline
plot = explore.apply(df_forest, model.precision_series, k=1000, dropna=False).plot(figsize=(15,8))
plot.axhline(y=0.4,xmin=0,xmax=1000,c="red",linewidth=0.5,zorder=0)
plot.set_xlabel('Number of Inspections', fontsize = 18)
plot.set_ylabel('Precision', fontsize = 18)

# %%
#df_forest[(df_forest.train_years == 3) & (df_forest.year == 2013)]
import matplotlib as plt
plt.style.use('ggplot')
plot = explore.apply(df_forest[(df_forest.train_years == 3) & (df_forest.year == 2013)], model.precision_series, k=800, dropna=False).plot(figsize=(15,10))
plot.axhline(y=0.4,xmin=0,xmax=800,c="red",linewidth=0.5,zorder=0)

# %%
explore.apply(df_forest, model.precision, k=800, dropna=False)

# %%
explore.apply(df_forest, model.count)

# %%
plot = explore.apply(df_forest, model.count_series, k=500, dropna=False).plot(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     226
#     227     if 'png' in formats:
# --> 228         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     229     if 'retina' in formats or 'png2x' in formats:
#     230         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2165                     orientation=orientation,
#    2166                     dryrun=True,
# -> 2167                     **kwargs)
#    2168                 renderer = self.figure._cachedRenderer
#    2169                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     503
#     504     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 505         FigureCanvasAgg.draw(self)
#     506         renderer = self.get_renderer()
#     507         original_dpi = renderer.dpi
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw(self)
#     449
#     450         try:
# --> 451             self.figure.draw(self.renderer)
#     452         finally:
#     453             RendererAgg.lock.release()
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53     def draw_wrapper(artist, renderer, *args, **kwargs):
#      54         before(artist, renderer)
# ---> 55         draw(artist, renderer, *args, **kwargs)
#      56         after(artist, renderer)
#      57
#
# /usr/lib/pymodules/python2.7/matplotlib/figure.pyc in draw(self, renderer)
#    1032         dsu.sort(key=itemgetter(0))
#    1033         for zorder, a, func, args in dsu:
# -> 1034             func(*args)
#    1035
#    1036         renderer.close_group('figure')
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53     def draw_wrapper(artist, renderer, *args, **kwargs):
#      54         before(artist, renderer)
# ---> 55         draw(artist, renderer, *args, **kwargs)
#      56         after(artist, renderer)
#      57
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in draw(self, renderer, inframe)
#    2084
#    2085         for zorder, a in dsu:
# -> 2086             a.draw(renderer)
#    2087
#    2088         renderer.close_group('axes')
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53     def draw_wrapper(artist, renderer, *args, **kwargs):
#      54         before(artist, renderer)
# ---> 55         draw(artist, renderer, *args, **kwargs)
#      56         after(artist, renderer)
#      57
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1094
#    1095         for tick in ticks_to_draw:
# -> 1096             tick.draw(renderer)
#    1097
#    1098         # scale up the axis label box to also find the neighbors, not
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53     def draw_wrapper(artist, renderer, *args, **kwargs):
#      54         before(artist, renderer)
# ---> 55         draw(artist, renderer, *args, **kwargs)
#      56         after(artist, renderer)
#      57
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in draw(self, renderer)
#     232         if midPoint:
#     233             if self.gridOn:
# --> 234                 self.gridline.draw(renderer)
#     235             if self.tick1On:
#     236                 self.tick1line.draw(renderer)
#
# /usr/lib/pymodules/python2.7/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53     def draw_wrapper(artist, renderer, *args, **kwargs):
#      54         before(artist, renderer)
# ---> 55         draw(artist, renderer, *args, **kwargs)
#      56         after(artist, renderer)
#      57
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in draw(self, renderer)
#     560                         drawFunc(pe_renderer, gc, tpath, affine_frozen)
#     561                 else:
# --> 562                     drawFunc(renderer, gc, tpath, affine.frozen())
#     563
#     564         if self._marker:
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in _draw_lines(self, renderer, gc, path, trans)
#     936
#     937     def _draw_lines(self, renderer, gc, path, trans):
# --> 938         self._lineFunc(renderer, gc, path, trans)
#     939
#     940     def _draw_steps_pre(self, renderer, gc, path, trans):
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in _draw_solid(self, renderer, gc, path, trans)
#     976     def _draw_solid(self, renderer, gc, path, trans):
#     977         gc.set_linestyle('solid')
# --> 978         renderer.draw_path(gc, path, trans)
#     979
#     980     def _draw_dashed(self, renderer, gc, path, trans):
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in draw_path(self, gc, path, transform, rgbFace)
#     143                 self._renderer.draw_path(gc, p, transform, rgbFace)
#     144         else:
# --> 145             self._renderer.draw_path(gc, path, transform, rgbFace)
#     146
#     147     def draw_mathtext(self, gc, x, y, s, prop, angle):
#
# TypeError: cannot return std::string from Unicode object

# %%
plot = explore.apply(df_forest, model.recall_series, k=500, dropna=True).plot(figsize=(15,10))

#.get_result['y'].sort by score descending and take first k rows

# %%
explore.apply(df, model.roc_auc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-36330d00b603> in <module>()
# ----> 1 explore.apply(df, model.roc_auc)
#       2
#
# AttributeError: 'module' object has no attribute 'roc_auc'

# %%
#.get_result['y'].sort by score descending and take first k rows
model_set1[0].get_result()['y'].sort_values('score', ascending = False).head(300).query('true == False')
# Out:
#                           true     score active_today     br enforcement  \
# rcra_id      date
# NYR000197780 2013-01-01  False  0.840000         True  False       False
# NYR000202218 2013-01-01  False  0.736617         True  False       False
# NYD077444263 2013-01-01  False  0.734000         True  False       False
# NYD980593636 2013-01-01  False  0.726000         True  False       False
# NYD980592497 2013-01-01  False  0.720000         True  False       False
# NYR000182444 2013-01-01  False  0.720000         True  False       False
# NYD002223550 2013-01-01  False  0.708000         True  False       False
# NYR000162743 2013-01-01  False  0.698000         True  False       False
#
#                         enforcement_epa enforcement_state evaluation  \
# rcra_id      date
# NYR000197780 2013-01-01            None             False       True
# NYR000202218 2013-01-01            None             False       True
# NYD077444263 2013-01-01            None             False       True
# NYD980593636 2013-01-01            None             False       True
# NYD980592497 2013-01-01            None             False       True
# NYR000182444 2013-01-01            None             False       True
# NYD002223550 2013-01-01            None             False       True
# NYR000162743 2013-01-01            None             False       True
#
#                         evaluation_epa evaluation_state  \
# rcra_id      date
# NYR000197780 2013-01-01          False             True
# NYR000202218 2013-01-01          False             True
# NYD077444263 2013-01-01          False             True
# NYD980593636 2013-01-01          False             True
# NYD980592497 2013-01-01          False             True
# NYR000182444 2013-01-01          False             True
# NYD002223550 2013-01-01          False             True
# NYR000162743 2013-01-01          False             True
#
#                                   ...           region state violation  \
# rcra_id      date                 ...
# NYR000197780 2013-01-01           ...              2.0    NY     False
# NYR000202218 2013-01-01           ...              2.0    NY     False
# NYD077444263 2013-01-01           ...              2.0    NY     False
# NYD980593636 2013-01-01           ...              2.0    NY     False
# NYD980592497 2013-01-01           ...              2.0    NY     False
# NYR000182444 2013-01-01           ...              2.0    NY     False
# NYD002223550 2013-01-01           ...              2.0    NY     False
# NYR000162743 2013-01-01           ...              2.0    NY     False
#
#                          violation_epa violation_state violation_types  \
# rcra_id      date
# NYR000197780 2013-01-01           None           False              []
# NYR000202218 2013-01-01           None           False              []
# NYD077444263 2013-01-01           None           False              []
# NYD980593636 2013-01-01           None           False              []
# NYD980592497 2013-01-01           None           False              []
# NYR000182444 2013-01-01           None           False              []
# NYD002223550 2013-01-01           None           False              []
# NYR000162743 2013-01-01           None           False              []
#
#                         violation_types_epa violation_types_state  \
# rcra_id      date
# NYR000197780 2013-01-01                  []                    []
# NYR000202218 2013-01-01                  []                    []
# NYD077444263 2013-01-01                  []                    []
# NYD980593636 2013-01-01                  []                    []
# NYD980592497 2013-01-01                  []                    []
# NYR000182444 2013-01-01                  []                    []
# NYD002223550 2013-01-01                  []                    []
# NYR000162743 2013-01-01                  []                    []
#
#                         last_investigation_days last_investigation_date
# rcra_id      date
# NYR000197780 2013-01-01                     NaN                     NaT
# NYR000202218 2013-01-01                   202.0              2012-06-13
# NYD077444263 2013-01-01                   166.0              2012-07-19
# NYD980593636 2013-01-01                    48.0              2012-11-14
# NYD980592497 2013-01-01                    26.0              2012-12-06
# NYR000182444 2013-01-01                     NaN                     NaT
# NYD002223550 2013-01-01                  1166.0              2009-10-23
# NYR000162743 2013-01-01                     NaN                     NaT
#
# [8 rows x 31 columns]

# %%
#### Looking at logistic regression results

model_set_logistic = model_set1 = epa.model.workflow.violation_state_logistic()
step.load(model_set_logistic)
# Out:
# [FitPredict(inputs=[Construct(C=0.1, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.1, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.1, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.1, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True)]

# %%
df = explore.to_dataframe(model_set_logistic)

# %%
df
# Out:
#    train_years  year                                               step
# 0            2  2013  FitPredict(inputs=[Construct(C=0.1, __class_na...
# 1            2  2015  FitPredict(inputs=[Construct(C=0.1, __class_na...
# 2            3  2013  FitPredict(inputs=[Construct(C=0.1, __class_na...
# 3            3  2015  FitPredict(inputs=[Construct(C=0.1, __class_na...

# %%
# %matplotlib inline
plot = explore.apply(df, model.precision_series, k=800, dropna=False).plot(figsize=(15,10))
plot.axhline(y=0.4,xmin=0,xmax=500,c="red",linewidth=0.5,zorder=0)

# %%
model_set_logistic[0].get_result()['feature_importances']
# Out:
#                                                feature  importance
# 120          investigations_facility_5y_violation_prop    0.295445
# 728                                          naics2_33    0.202182
# 711                                           naics1_6    0.202150
# 281        investigations_facility_all_agency_epa_prop    0.201593
# 377  investigations_facility_all_sep_scheduled_comp...    0.192718
# 300   investigations_facility_all_violation_state_prop    0.188548
# 714                                          naics2_45    0.181064
# 630             handlers_facility_all_handler_sqg_prop    0.172221
# 663   handlers_facility_all_handler_include_in_br_prop    0.146721
# 388            icis_fec_facility_5y_st_lcl_penalty_max    0.125016
# 730                                          naics2_44    0.116958
# 287        investigations_facility_all_violation_state    0.111553
# 451             manifest_facility_all_line_items_count    0.094445
# 54    rmp_facility_5y_comp_monitor_comprehensive_count    0.087064
# 737                                          naics2_31    0.085801
# 21                        handler_transporter_activity    0.082435
# 462                         handlers_facility_5y_count    0.078683
# 487  handlers_facility_5y_handler_onsite_burner_exe...    0.075849
# 666  handlers_facility_all_handler_non_notifier_exe...    0.074222
# 720                                          naics2_71    0.072551
# 502    handlers_facility_5y_handler_include_in_br_prop    0.071287
# 657  handlers_facility_all_handler_used_oil_fuel_ma...    0.071026
# 501       handlers_facility_5y_handler_withdrawal_prop    0.064280
# 570  handlers_facility_1y_handler_universal_waste_d...    0.062039
# 126  investigations_facility_5y_formal_enforcement_...    0.060636
# 294      investigations_facility_all_citizen_complaint    0.057171
# 316  investigations_facility_all_enforcement_epa_count    0.056163
# 379                         icis_fec_facility_5y_count    0.055991
# 732                                          naics2_51    0.053603
# 662      handlers_facility_all_handler_withdrawal_prop    0.050875
# ..                                                 ...         ...
# 308  investigations_facility_all_multimedia_inspect...   -0.036236
# 676  handlers_facility_all_handler_land_type_other_...   -0.037775
# 85           rmp_facility_all_observed_deficiency_prop   -0.038737
# 60                 rmp_facility_5y_actual_end_date_min   -0.039126
# 712                                           naics1_9   -0.039221
# 427              icis_fec_facility_all_fed_penalty_max   -0.040125
# 332  investigations_facility_all_evaluation_to_viol...   -0.041218
# 606  handlers_facility_1y_handler_onsite_burner_exe...   -0.041680
# 490  handlers_facility_5y_handler_receives_waste_fr...   -0.043183
# 526  handlers_facility_5y_handler_recycler_activity...   -0.045165
# 586   handlers_facility_1y_handler_not_generator_count   -0.047389
# 396      icis_fec_facility_5y_activity_status_date_max   -0.047420
# 731                                          naics2_56   -0.047522
# 419  icis_fec_facility_all_total_cost_recovery_amt_min   -0.049281
# 687  handlers_facility_all_handler_recycler_activit...   -0.052062
# 649  handlers_facility_all_handler_furnace_exemptio...   -0.056697
# 299     investigations_facility_all_violation_epa_prop   -0.057865
# 453               manifest_facility_all_approx_qty_min   -0.060570
# 218  investigations_facility_1y_enforcement_state_prop   -0.065272
# 452               manifest_facility_all_approx_qty_max   -0.065384
# 653  handlers_facility_all_handler_used_oil_transpo...   -0.067357
# 248  investigations_facility_1y_evaluation_to_viola...   -0.074414
# 671          handlers_facility_all_handler_cesqg_count   -0.075598
# 282      investigations_facility_all_agency_state_prop   -0.081492
# 309          investigations_facility_all_sampling_prop   -0.085279
# 458             manifest_facility_all_waste_code_u_any   -0.085320
# 344      investigations_facility_all_diff_fmp_mpm_mean   -0.091736
# 593  handlers_facility_1y_handler_land_type_county_...   -0.121141
# 102            investigations_facility_5y_agency_state   -0.129728
# 41                                    handler_received   -0.191095
#
# [740 rows x 2 columns]

# %%
explore.apply(df, model.precision, k=800, dropna=False)
# Out:
# train_years  year
# 2            2013    0.654545
#              2015    0.628866
# 3            2013    0.736842
#              2015    0.630252
# Name: step, dtype: float64

# %%
# Load dataset ----- to check 
from
