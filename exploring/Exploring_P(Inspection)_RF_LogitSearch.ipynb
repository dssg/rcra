# %%
import epa.model.workflow
#model_set1 = epa.model.workflow.violation_state()
model_set2 = epa.model.workflow.violation_state_manifest_br_added() + epa.model.workflow.logit_exploring()


from drain import step
step.OUTPUTDIR = '/mnt/data/nysdec/epa-ny/drain/'

# %%
step.load(model_set2)
# Out:
# [FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(__class_name__='sklearn.ensemble.RandomForestClassifier',
#       criterion='entropy', max_features='sqrt', n_estimators=500, n_jobs=-1), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=2, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=3, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=4, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
# ...
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2012)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2013)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2014)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l1'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.0001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.001, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True),
#  FitPredict(inputs=[Construct(C=0.01, __class_name__='sklearn.linear_model.LogisticRegression',
#       penalty='l2'), EpaTransform(day=1, evaluation=False, exclude=set([]), handlers={}, icis={},
#         impute=True, include=set([]), investigations={},
#         investigations_expand_counts=False, month=1, normalize=True,
#         outcome_expr='aux.violation_state', region=None, rmp={},
#         train_query='aux.evaluation_state', train_years=5, year=2015)],
#        prefit=False, return_estimator=False,
#        return_feature_importances=True, return_predictions=True)]

# %%
model_set2[20].get_result()['feature_importances']
# Out:
#                                                feature  importance
# 143          investigations_facility_5y_violation_prop    0.014796
# 328         investigations_facility_all_violation_prop    0.012845
# 130               investigations_facility_5y_violation    0.012288
# 132         investigations_facility_5y_violation_state    0.010717
# 134       investigations_facility_5y_enforcement_state    0.010467
# 829                                          naics2_45    0.009005
# 416              handlers_facility_5y_handler_sqg_prop    0.008952
# 807                                           naics1_4    0.008771
# 456             handlers_facility_5y_handler_sqg_count    0.008764
# 835                                          naics2_44    0.008667
# 330   investigations_facility_all_violation_state_prop    0.008504
# 332  investigations_facility_all_enforcement_state_...    0.008335
# 577             handlers_facility_all_handler_sqg_prop    0.008212
# 809                                           naics1_6    0.007949
# 315              investigations_facility_all_violation    0.007890
# 7                                          handler_sqg    0.007817
# 311        investigations_facility_all_agency_epa_prop    0.007724
# 617            handlers_facility_all_handler_sqg_count    0.007553
# 319      investigations_facility_all_enforcement_state    0.007313
# 317        investigations_facility_all_violation_state    0.006914
# 309             investigations_facility_all_agency_epa    0.006766
# 816                                          naics2_61    0.006569
# 160  investigations_facility_5y_enforcement_state_c...    0.005720
# 170  investigations_facility_5y_violation_determine...    0.005589
# 126         investigations_facility_5y_agency_epa_prop    0.005523
# 156         investigations_facility_5y_violation_count    0.005347
# 158   investigations_facility_5y_violation_state_count    0.005247
# 811                                           naics1_8    0.005230
# 820                                          naics2_81    0.005230
# 145    investigations_facility_5y_violation_state_prop    0.005180
# ..                                                 ...         ...
# 654               manifest_facility_5y_approx_qty_mean   -0.003945
# 678              manifest_facility_all_approx_qty_mean   -0.003945
# 356  investigations_facility_all_actual_return_to_c...   -0.003952
# 500  handlers_facility_1y_handler_land_type_county_...   -0.003953
# 404  investigations_facility_all_enforcement_action...   -0.003954
# 355  investigations_facility_all_violation_determin...   -0.004072
# 571    handlers_facility_all_handler_non_notifier_prop   -0.004124
# 308                  investigations_facility_all_count   -0.004151
# 129      investigations_facility_5y_agency_state_count   -0.004187
# 357  investigations_facility_all_enforcement_action...   -0.004193
# 402  investigations_facility_all_violation_determin...   -0.004463
# 758                   br_facility_5y_managed_tons_skew   -0.004520
# 339          investigations_facility_all_sampling_prop   -0.004564
# 666               manifest_facility_1y_approx_qty_mean   -0.004568
# 352         investigations_facility_all_sampling_count   -0.004808
# 681               manifest_facility_all_approx_qty_std   -0.004812
# 657                manifest_facility_5y_approx_qty_std   -0.004812
# 314     investigations_facility_all_agency_state_count   -0.004898
# 403  investigations_facility_all_actual_return_to_c...   -0.005069
# 813                                          naics2_56   -0.005171
# 127       investigations_facility_5y_agency_state_prop   -0.005523
# 669                manifest_facility_1y_approx_qty_std   -0.006347
# 50                         br_source_remediation_waste   -0.006349
# 454   handlers_facility_5y_handler_not_generator_count   -0.006944
# 615  handlers_facility_all_handler_not_generator_count   -0.006948
# 575   handlers_facility_all_handler_not_generator_prop   -0.007236
# 125            investigations_facility_5y_agency_state   -0.007480
# 312      investigations_facility_all_agency_state_prop   -0.007724
# 414    handlers_facility_5y_handler_not_generator_prop   -0.008052
# 5                                handler_not_generator   -0.008926
#
# [838 rows x 2 columns]
